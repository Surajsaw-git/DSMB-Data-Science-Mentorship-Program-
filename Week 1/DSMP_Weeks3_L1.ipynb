# %%
print("hello Suraj ")
print("DSMP Week 3 OOP L1")
# Out:
# hello Suraj
# DSMP Week 3 OOP L1

# %%
L=[1,2,3,4]
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3021271856.py in <cell line: 0>()
#       1 L=[1,2,3,4]
# ----> 2 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s="hello Suraj"
s.upper('x')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1127389388.py in <cell line: 0>()
#       1 s="hello Suraj"
# ----> 2 s.upper('x')
#
# TypeError: str.upper() takes no arguments (1 given)

# %%
L=[1,2,3,4]
print(type(L))
# Out:
# <class 'list'>

# %%
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3930800027.py in <cell line: 0>()
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %% [markdown]
# #Class
# Class is a blueprint.
# ####We use Pascal Case for write Classs name
# i.e HelloWorld (When we write two words in Class name then both the words start with capital letter )
#
# ##Syntax to create an object
# object_Name = ClassName()

# %%
#syntax to create an object
L=[1,2,3,4]
# Out:
# [1, 2, 3, 4]

# %%
L=list()
L
# Out:
# []

# %%
s=str()
s
# Out:
# ''

# %% [markdown]
# #ATM
# #### Constructor : it is special function , for execution it don't need call the constuctor eplicitly

# %%
class Atm:
  # Constructor : it is special function
  def __init__(self):
    self.pin=''
    self.balance=0
    self.menu()

  def menu(self):
    user_input=input("""
    Hii How I can help you ?
    1. To create Pin
    2. To Change Pin
    3. To check Balance
    4. To Withdraw
    5. To Exit
    """)

  #   if user_input == '1':
  #     #create pin
  #   elif user_input == '2':
  #     #change pin
  #   elif user_input == '3':
  #     #check balance
  #   elif user_input == '4':
  #     #withdraw
  #     pass
  #   else :
  #     exit()

  # def create_pin(self):

# %%
obj = Atm()
# Out:
#     Hii How I can help you ?
#     1. To create Pin
#     2. To Change Pin
#     3. To check Balance
#     4. To Withdraw
#     5. To Exit
#     5
