# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# Write your code here
print("data","science","Mentorship","program",sep="-",end="started-")
print("")
print("By","CampusX",sep="-")
# Out:
# data-science-Mentorship-programstarted-
# By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# Write your code here
#°F = (°C × 9/5) + 32
#take user input as Celsius and convert it into fahrenheit

Celsius=int(input("Enter Celsius value"))
Fahrenheit=(Celsius*9/5)+32
print("Fahrenheit is : ",Fahrenheit)
# Out:
# Enter Celsius value85
# Fahrenheit is :  185.0

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
# Write your code here
a=int(input("Enter first number"))
b=int(input("Enter second number"))
print("Before swapping")
print("a=",a)
print("b=",b)
c=a
a=b
b=c
print("After swapping")
print("a=",a)
print("b=",b)
# Out:
# Enter first number55
# Enter second number26
# Before swapping
# a= 55
# b= 26
# After swapping
# a= 26
# b= 55

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
# Write your code here
# Formula : distance=((x2-x1)**2+(y2-y1)**2)**0.5
# take four user input
x1=int(input("Enter X1 number"))
y1=int(input("Enter Y1 number"))

x2=int(input("Enter X2 number"))
y2=int(input("Enter Y2 number"))
print("Coordinates of both points :")
print("First point is : (",x1,",",y1,")")
print("Second point is : (",x2,",",y2,")")
distance=((x2-x1)**2+(y2-y1)**2)**0.5
print("Distance between two points is : ",distance)
# Out:
# Enter X1 number5
# Enter Y1 number8
# Enter X2 number2
# Enter Y2 number3
# Coordinates of both points :
# First point is : ( 5 , 8 )
# Second point is : ( 2 , 3 )
# Distance between two points is :  5.830951894845301

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
# Write your code here
#take user input as principle value , rate of interest and time period
#use formula : SI = p*t*r/100
p=int(input("Enter principle value : "))   #principle valu
t=int(input("Enter time period : "))       #time period
r=int(input("Enter rate of interest :  "))  #rate of interest
SI=(p*t*r)/100
print("Simple interest is : ",SI)
# Out:
# Enter principle value : 100000
# Enter time period : 5
# Enter rate of interest : 5
# Simple interest is :  25000.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
# Write your code here
heads=int(input("Enter number of heads : "))
legs=int(input("Enter number of legs : "))
#use formula :
# d for dog
# c for chiken
# d + c = total heads
# 4d + 2c = total legs
# c = (total heads - total legs )/2
chiken=(4*heads-legs)/2
dog=heads-chiken
print("Number of chiken is : ",chiken)
print("Number of dog is : ",dog)

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
# Write your code here
#sum of squares of n number formula
# s = n(n+1)(2n+1)/6
# take user input as n
n=int(input("Enter number : "))
s=(n*(n+1)*(2*n+1))/6
print("Sum of squares of first n natural numbers is : ",s)

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# Write your code here
#use formula 1st : to find d, d = a2-a1
# to find An = (n-1)9+a1
#take user input a1, a2 and n
a1=int(input("Enter first term : "))
a2=int(input("Enter second term : "))
d=a2-a1
n=int(input("Enter value of n : "))
An=(n-1)*d+a1
print("Nth Term of the series is : ",An)

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
# Write your code here
#use formula sum = ((n1*d2) + (n2* d1))/d1*d2
#take user input as n1 , n2 , d1 and d2
# calculate sum of two fractions number
n1=int(input("Enter numerator of first fraction : "))
d1=int(input("Enter denominator of first fraction : "))

n2=int(input("Enter numerator of second fraction : "))
d2=int(input("Enter denominator of second fraction : "))
sum=((n1*d2)+(n2*d1))/(d1*d2)
print("Sum of two fractions is : ",sum)

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
#find volume of milk tank using formula L * B * H
#find volume of glass using formula 3.14 * r * r * h
# find no. of glass of milk using formula : volume of milk tank / volume of milk glass

H=20
L=20
B=20
volume_of_milk_tank=H*L*B
h=3
r=1
volume_of_glass_milk=3.14*r*r*h
No_glass=volume_of_milk_tank/volume_of_glass_milk
print("No of milk glass : ",int(No_glass))
