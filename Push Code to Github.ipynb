# %%
print()

# %%
# 1. Mount Drive and Move to Folder
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/DSMP

# 2. Re-initialize to fix the "not a git repository" error
# !git init
# !git config --global user.email "surajsaw7050500@gmail.com"
# !git config --global user.name "suraj saw"

# 3. Connect to GitHub (PASTE YOUR NEW TOKEN BELOW)
# !git remote add origin https://<YOUR_NEW_TOKEN>@github.com/Surajsaw-git/DSMB-Data-Science-Mentorship-Program-.git
# !git branch -M main

# 4. Final Push
# !git add .
# !git commit -m "Initial commit: Organized DSMP session work"
# !git push -u origin main

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/DSMP
# !rm -rf .git
# !rm -rf .gitignore
# Out:
# /content/drive/MyDrive/DSMP

# %%
with open('.gitignore', 'w') as f:
    f.write('.ipynb_checkpoints/\n')
print(".gitignore file created successfully!")
# Out:
# .gitignore file created successfully!

# %%
# 1. Initialize a brand new Git repository
# !git init
# !git config --global user.email "surajsaw7050500@gmail.com"
# !git config --global user.name "suraj saw"
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/DSMP/.git/

# %%
# 3. Push your Week 1 and Week 2 folders
# !git branch -M main
# !git add .
# !git commit -m "Initial commit: Organized Data Science session notebooks"
# !git push -u origin main
# Out:
# [main (root-commit) 8f4733a] Initial commit: Organized Data Science session notebooks
#  16 files changed, 16 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 DSMP Download/Copy of python-tuple-sets-dictionary.ipynb
#  create mode 100644 DSMP Download/Copy of session-4-python-lists.ipynb
#  create mode 100644 DSMP Interview/Interview_1_Questions_Ans.ipynb
#  create mode 100644 Untitled0.ipynb
#  create mode 100644 Week 1/DSA_topological_sort.ipynb
#  create mode 100644 Week 1/DSApython.ipynb
#  create mode 100644 Week 1/DSMP_Weeks3_L1.ipynb
#  create mode 100644 Week 1/pythonDSMPWeekS1.ipynb
#  create mode 100644 Week 1/pythonDSMPWeekS2.ipynb
#  create mode 100644 Week 1/pythonDSMPWeekS3.ipynb
#  create mode 100644 Week 1/session-1-tasks.ipynb
#  create mode 100644 Week 1/session-2-task.ipynb
#  create mode 100644 Week 1/session-3-task.ipynb
#  create mode 100644 Week 2/Session 4 - List in Python DSMP.ipynb
# ...

# %%
# 1. Navigate to your DSMP folder
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/DSMP

# 2. Sync with GitHub (Important: This pulls any changes you made on the website)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/DSMP

# %%
# 1. Initialize a brand new Git repository
# !git init
# !git config --global user.email "surajsaw7050500@gmail.com"
# !git config --global user.name "suraj saw"
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# 3. Add and Push your new Week 3 work
# !git add .
# !git commit -m "Update: Added Data Science session work"
# !git push origin main
# Out:
# [main b80073d] Update: Added Data Science session work
#  7 files changed, 7 insertions(+), 4 deletions(-)
#  rewrite Untitled0.ipynb (64%)
#  create mode 100644 Week 1/Copy of session-2-task-solutions.ipynb
#  rewrite Week 1/session-3-task.ipynb (93%)
#  create mode 100644 Week 2/Copy of session-4-task.ipynb
#  create mode 100644 Week 2/Copy of session-5-task.ipynb
#  rewrite Week 2/Session 5 Tuple Sets Dict DSMP.ipynb (60%)
# Enumerating objects: 18, done.
# Counting objects: 100% (18/18), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (11/11), done.
# Writing objects: 100% (11/11), 151.75 KiB | 2.53 MiB/s, done.
# Total 11 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 5 local objects.
# To https://github.com/Surajsaw-git/DSMB-Data-Science-Mentorship-Program-.git
#    8f4733a..b80073d  main -> main
